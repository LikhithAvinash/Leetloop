# %% [markdown]
# # Welcome to the start of your adventure in Agentic AI

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Are you ready for action??</h2>
#             <span style="color:#ff7800;">Have you completed all the setup steps in the <a href="../setup/">setup</a> folder?<br/>
#             Have you read the <a href="../README.md">README</a>? Many common questions are answered here!<br/>
#             Have you checked out the guides in the <a href="../guides/01_intro.ipynb">guides</a> folder?<br/>
#             Well in that case, you're ready!!
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/tools.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#00bfff;">This code is a live resource - keep an eye out for my updates</h2>
#             <span style="color:#00bfff;">I push updates regularly. As people ask questions or have problems, I add more examples and improve explanations. As a result, the code below might not be identical to the videos, as I've added more steps and better comments. Consider this like an interactive book that accompanies the lectures.<br/><br/>
#             I try to send emails regularly with important updates related to the course. You can find this in the 'Announcements' section of Udemy in the left sidebar. You can also choose to receive my emails via your Notification Settings in Udemy. I'm respectful of your inbox and always try to add value with my emails!
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ### And please do remember to contact me if I can help
#
# And I love to connect: https://www.linkedin.com/in/eddonner/
#
#
# ### New to Notebooks like this one? Head over to the guides folder!
#
# Just to check you've already added the Python and Jupyter extensions to Cursor, if not already installed:
# - Open extensions (View >> extensions)
# - Search for python, and when the results show, click on the ms-python one, and Install it if not already installed
# - Search for jupyter, and when the results show, click on the Microsoft one, and Install it if not already installed
# Then View >> Explorer to bring back the File Explorer.
#
# And then:
# 1. Click where it says "Select Kernel" near the top right, and select the option called `.venv (Python 3.12.9)` or similar, which should be the first choice or the most prominent choice. You may need to choose "Python Environments" first.
# 2. Click in each "cell" below, starting with the cell immediately below this text, and press Shift+Enter to run
# 3. Enjoy!
#
# After you click "Select Kernel", if there is no option like `.venv (Python 3.12.9)` then please do the following:
# 1. On Mac: From the Cursor menu, choose Settings >> VS Code Settings (NOTE: be sure to select `VSCode Settings` not `Cursor Settings`);
# On Windows PC: From the File menu, choose Preferences >> VS Code Settings(NOTE: be sure to select `VSCode Settings` not `Cursor Settings`)
# 2. In the Settings search bar, type "venv"
# 3. In the field "Path to folder with a list of Virtual Environments" put the path to the project root, like C:\Users\username\projects\agents (on a Windows PC) or /Users/username/projects/agents (on Mac or Linux).
# And then try again.
#
# Having problems with missing Python versions in that list? Have you ever used Anaconda before? It might be interferring. Quit Cursor, bring up a new command line, and make sure that your Anaconda environment is deactivated:
# `conda deactivate`
# And if you still have any problems with conda and python versions, it's possible that you will need to run this too:
# `conda config --set auto_activate_base false`
# and then from within the Agents directory, you should be able to run `uv python list` and see the Python 3.12 version.

# %%
# First let's do an import. If you get an Import Error, double check that your Kernel is correct..

from dotenv import load_dotenv

# %%
# Next it's time to load the API keys into environment variables
# If this returns false, see the next cell!

load_dotenv(override=True)
# Out:
# True

# %% [markdown]
# ### Wait, did that just output `False`??
#
# If so, the most common reason is that you didn't save your `.env` file after adding the key! Be sure to have saved.
#
# Also, make sure the `.env` file is named precisely `.env` and is in the project root directory (`agents`)
#
# By the way, your `.env` file should have a stop symbol next to it in Cursor on the left, and that's actually a good thing: that's Cursor saying to you, "hey, I realize this is a file filled with secret information, and I'm not going to send it to an external AI to suggest changes, because your keys should not be shown to anyone else."

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Final reminders</h2>
#             <span style="color:#ff7800;">1. If you're not confident about Environment Variables or Web Endpoints / APIs, please read Topics 3 and 5 in this <a href="../guides/04_technical_foundations.ipynb">technical foundations guide</a>.<br/>
#             2. If you want to use AIs other than OpenAI, like Gemini, DeepSeek or Ollama (free), please see the first section in this <a href="../guides/09_ai_apis_and_ollama.ipynb">AI APIs guide</a>.<br/>
#             3. If you ever get a Name Error in Python, you can always fix it immediately; see the last section of this <a href="../guides/06_python_foundations.ipynb">Python Foundations guide</a> and follow both tutorials and exercises.<br/>
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# Check the key - if you're not using OpenAI, check whichever key you're using! Ollama doesn't need a key.

import os
openai_api_key = os.getenv('GEMINI_API_KEY')

if openai_api_key:
    print(f"Gemini API Key exists and begins {openai_api_key[:8]}")
else:
    print("Gemini API Key not set - please head to the troubleshooting guide in the setup folder")
# Out:
# Gemini API Key exists and begins AIzaSyC7

# %%
# And now - the all important import statement
# If you get an import error - head over to troubleshooting in the Setup folder
# Even for other LLM providers like Gemini, you still use this OpenAI import - see Guide 9 for why

from google.generativeai import GenerativeModel, configure

# Configure the Gemini API
configure(api_key=os.environ["GEMINI_API_KEY"])
# Out:
# /tmp/ipykernel_10566/2751177945.py:5: FutureWarning:
#
# All support for the `google.generativeai` package has ended. It will no longer be receiving
# updates or bug fixes. Please switch to the `google.genai` package as soon as possible.
# See README for more details:
#
# https://github.com/google-gemini/deprecated-generative-ai-python/blob/main/README.md
#
#   from google.generativeai import GenerativeModel, configure

# %%
# And now we'll create an instance of the OpenAI class
# If you're not sure what it means to create an instance of a class - head over to the guides folder (guide 6)!
# If you get a NameError - head over to the guides folder (guide 6)to learn about NameErrors - always instantly fixable
# If you're not using OpenAI, you just need to slightly modify this - precise instructions are in the AI APIs guide (guide 9)

# Load the Gemini model (use gemini-1.5-flash, cheap & fast)
model = GenerativeModel("models/gemini-2.5-flash")

# %%
# Create a list of messages in the familiar OpenAI format

messages = [{"role": "user", "content": "What is 2+2?"}]

# %%
# And now call it! Any problems, head to the troubleshooting guide
# This uses GPT 4.1 nano, the incredibly cheap model
# The APIs guide (guide 9) has exact instructions for using even cheaper or free alternatives to OpenAI
# If you get a NameError, head to the guides folder (guide 6) to learn about NameErrors - always instantly fixable

# Convert messages into a single prompt
prompt = messages[0]["content"]
response = model.generate_content(prompt)
print(response.text)
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1777959662.333301    8130 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# 2 + 2 = 4

# %%
# And now - let's ask for a question:

question = "Please propose a hard, challenging question to assess someone's IQ. Respond only with the question."
messages = [{"role": "user", "content": question}]

# %%
from google.generativeai import GenerativeModel, configure
import os

configure(api_key=os.environ["GEMINI_API_KEY"])
model = GenerativeModel("models/gemini-2.5-flash")

question_1 = "Give me a hard IQ question. Respond only with the question that is mathematical"


response = model.generate_content(question_1)
print(response.text)
# Out:
# E0000 00:00:1777960344.569698    8130 alts_credentials.cc:93] ALTS creds ignored. Not running on GCP and untrusted ALTS is not enabled.
# Consider a sequence $x_n$ where $x_1 = 7$, and $x_{n+1}$ is the smallest integer greater than $x_n$ such that the sum of the digits of $x_{n+1}$ is a prime number and the product of the digits of $x_{n+1}$ is also a prime number. What is $x_4$?

# %%
# form a new messages list
# We want to ask the LLM to answer the question it just generated!
generated_question = response.text
messages = [{"role": "user", "content": f"What is the answer to this question?\n\n{generated_question}"}]

# %%
# Ask it again

# Gemini uses a prompt string instead of OpenAI-style messages
prompt = messages[0]["content"]
response = model.generate_content(prompt)

answer = response.text
print(answer)
# Out:
# Let the integer be $x$.
#
# We are given two conditions:
#
# 1.  "when multiplied by 7, leaves a remainder of 1 when divided by 10"
#     This can be written as a congruence: $7x \equiv 1 \pmod{10}$
#
# 2.  "when multiplied by 8, leaves a remainder of 1 when divided by 13"
#     This can be written as a congruence: $8x \equiv 1 \pmod{13}$
#
# Let's solve each congruence:
#
# **Congruence 1: $7x \equiv 1 \pmod{10}$**
# To find $x$, we need to find the multiplicative inverse of 7 modulo 10.
# We can test values:
# $7 \times 1 = 7$
# $7 \times 2 = 14 \equiv 4 \pmod{10}$
# $7 \times 3 = 21 \equiv 1 \pmod{10}$
# So, multiplying by 3 on both sides:
# $3 \times 7x \equiv 3 \times 1 \pmod{10}$
# $21x \equiv 3 \pmod{10}$
# $x \equiv 3 \pmod{10}$
# This means $x$ can be 3, 13, 23, 33, 43, 53, 63, 73, 83, ...
#
# **Congruence 2: $8x \equiv 1 \pmod{13}$**
# To find $x$, we need to find the multiplicative inverse of 8 modulo 13.
# We can test values:
# $8 \times 1 = 8$
# $8 \times 2 = 16 \equiv 3 \pmod{13}$
# $8 \times 3 = 24 \equiv 11 \pmod{13}$
# $8 \times 4 = 32 \equiv 6 \pmod{13}$
# $8 \times 5 = 40 \equiv 1 \pmod{13}$
# So, multiplying by 5 on both sides:
# $5 \times 8x \equiv 5 \times 1 \pmod{13}$
# $40x \equiv 5 \pmod{13}$
# Since $40 = 3 \times 13 + 1$, we have $40 \equiv 1 \pmod{13}$:
# $x \equiv 5 \pmod{13}$
# This means $x$ can be 5, 18, 31, 44, 57, 70, 83, 96, ...
#
# Now we need to find the smallest positive integer $x$ that satisfies both conditions:
# $x \equiv 3 \pmod{10}$
# $x \equiv 5 \pmod{13}$
#
# We can list the numbers satisfying the first congruence and check them against the second:
# Numbers $x \equiv 3 \pmod{10}$:
# 3 ($3 \not\equiv 5 \pmod{13}$)
# 13 ($13 \not\equiv 5 \pmod{13}$, actually $13 \equiv 0 \pmod{13}$)
# 23 ($23 \equiv 10 \pmod{13}$, $10 \not\equiv 5 \pmod{13}$)
# 33 ($33 \equiv 7 \pmod{13}$, $7 \not\equiv 5 \pmod{13}$)
# 43 ($43 \equiv 4 \pmod{13}$, $4 \not\equiv 5 \pmod{13}$)
# 53 ($53 \equiv 1 \pmod{13}$, $1 \not\equiv 5 \pmod{13}$)
# 63 ($63 \equiv 11 \pmod{13}$, $11 \not\equiv 5 \pmod{13}$)
# 73 ($73 \equiv 8 \pmod{13}$, $8 \not\equiv 5 \pmod{13}$)
# 83 ($83 \equiv 5 \pmod{13}$, which satisfies the second condition!)
#
# So, the smallest positive integer is 83.
#
# Let's verify:
# For $x = 83$:
# 1.  $7 \times 83 = 581$. When $581$ is divided by $10$, the remainder is $1$. (Correct)
# 2.  $8 \times 83 = 664$. When $664$ is divided by $13$, $664 = 13 \times 51 + 1$. The remainder is $1$. (Correct)
#
# The final answer is $\boxed{83}$.

# %%
from IPython.display import Markdown, display

display(Markdown(answer))
# Out:
# Let the integer be $x$.
#
# We are given two conditions:
#
# 1.  "when multiplied by 7, leaves a remainder of 1 when divided by 10"
#     This can be written as a congruence: $7x \equiv 1 \pmod{10}$
#
# 2.  "when multiplied by 8, leaves a remainder of 1 when divided by 13"
#     This can be written as a congruence: $8x \equiv 1 \pmod{13}$
#
# Let's solve each congruence:
#
# **Congruence 1: $7x \equiv 1 \pmod{10}$**
# To find $x$, we need to find the multiplicative inverse of 7 modulo 10.
# We can test values:
# $7 \times 1 = 7$
# $7 \times 2 = 14 \equiv 4 \pmod{10}$
# $7 \times 3 = 21 \equiv 1 \pmod{10}$
# So, multiplying by 3 on both sides:
# $3 \times 7x \equiv 3 \times 1 \pmod{10}$
# $21x \equiv 3 \pmod{10}$
# $x \equiv 3 \pmod{10}$
# This means $x$ can be 3, 13, 23, 33, 43, 53, 63, 73, 83, ...
#
# **Congruence 2: $8x \equiv 1 \pmod{13}$**
# To find $x$, we need to find the multiplicative inverse of 8 modulo 13.
# We can test values:
# $8 \times 1 = 8$
# $8 \times 2 = 16 \equiv 3 \pmod{13}$
# $8 \times 3 = 24 \equiv 11 \pmod{13}$
# $8 \times 4 = 32 \equiv 6 \pmod{13}$
# $8 \times 5 = 40 \equiv 1 \pmod{13}$
# So, multiplying by 5 on both sides:
# $5 \times 8x \equiv 5 \times 1 \pmod{13}$
# $40x \equiv 5 \pmod{13}$
# Since $40 = 3 \times 13 + 1$, we have $40 \equiv 1 \pmod{13}$:
# $x \equiv 5 \pmod{13}$
# This means $x$ can be 5, 18, 31, 44, 57, 70, 83, 96, ...
#
# Now we need to find the smallest positive integer $x$ that satisfies both conditions:
# $x \equiv 3 \pmod{10}$
# $x \equiv 5 \pmod{13}$
#
# We can list the numbers satisfying the first congruence and check them against the second:
# Numbers $x \equiv 3 \pmod{10}$:
# 3 ($3 \not\equiv 5 \pmod{13}$)
# 13 ($13 \not\equiv 5 \pmod{13}$, actually $13 \equiv 0 \pmod{13}$)
# 23 ($23 \equiv 10 \pmod{13}$, $10 \not\equiv 5 \pmod{13}$)
# 33 ($33 \equiv 7 \pmod{13}$, $7 \not\equiv 5 \pmod{13}$)
# 43 ($43 \equiv 4 \pmod{13}$, $4 \not\equiv 5 \pmod{13}$)
# 53 ($53 \equiv 1 \pmod{13}$, $1 \not\equiv 5 \pmod{13}$)
# 63 ($63 \equiv 11 \pmod{13}$, $11 \not\equiv 5 \pmod{13}$)
# 73 ($73 \equiv 8 \pmod{13}$, $8 \not\equiv 5 \pmod{13}$)
# 83 ($83 \equiv 5 \pmod{13}$, which satisfies the second condition!)
#
# So, the smallest positive integer is 83.
#
# Let's verify:
# For $x = 83$:
# 1.  $7 \times 83 = 581$. When $581$ is divided by $10$, the remainder is $1$. (Correct)
# 2.  $8 \times 83 = 664$. When $664$ is divided by $13$, $664 = 13 \times 51 + 1$. The remainder is $1$. (Correct)
#
# The final answer is $\boxed{83}$.

# %% [markdown]
# # Congratulations!
#
# That was a small, simple step in the direction of Agentic AI, with your new environment!
#
# Next time things get more interesting...

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/exercise.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Exercise</h2>
#             <span style="color:#ff7800;">Now try this commercial application:<br/>
#             First ask the LLM to pick a business area that might be worth exploring for an Agentic AI opportunity.<br/>
#             Then ask the LLM to present a pain-point in that industry - something challenging that might be ripe for an Agentic solution.<br/>
#             Finally have 3 third LLM call propose the Agentic AI solution. <br/>
#             We will cover this at up-coming labs, so don't worry if you're unsure.. just give it a try!
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# First create the messages:

messages = [{'role':'user','content':'what is 2 + 2'}]

prompt = messages[0]['content']

response = model.generate_content(prompt)

answer = response.text

from IPython.display import Markdown, display

display(Markdown(answer))

# And repeat! In the next message, include the business idea within the message
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 7
#       3 messages = [{'role':'user','content':'Give a Hard question from Dsa'}]
#       5 prompt = messages[0]['content']
# ----> 7 response = model.generate_content(prompt)
#       9 answer = response.text
#      11 from IPython.display import Markdown, display
#
# File ~/Desktop/agents/.venv/lib/python3.12/site-packages/google/generativeai/generative_models.py:331, in GenerativeModel.generate_content(self, contents, generation_config, safety_settings, stream, tools, tool_config, request_options)
#     329         return generation_types.GenerateContentResponse.from_iterator(iterator)
#     330     else:
# --> 331         response = self._client.generate_content(
#     332             request,
#     333             **request_options,
#     334         )
#     335         return generation_types.GenerateContentResponse.from_response(response)
#     336 except google.api_core.exceptions.InvalidArgument as e:
#
# File ~/Desktop/agents/.venv/lib/python3.12/site-packages/google/ai/generativelanguage_v1beta/services/generative_service/client.py:835, in GenerativeServiceClient.generate_content(self, request, model, contents, retry, timeout, metadata)
#     832 self._validate_universe_domain()
#     834 # Send the request.
# --> 835 response = rpc(
#     836     request,
#     837     retry=retry,
#     838     timeout=timeout,
#     839     metadata=metadata,
#     840 )
#     842 # Done; return the response.
#     843 return response
#
# File ~/Desktop/agents/.venv/lib/python3.12/site-packages/google/api_core/gapic_v1/method.py:128, in _GapicCallable.__call__(self, timeout, retry, compression, *args, **kwargs)
#     125 if self._compression is not None:
#     126     kwargs["compression"] = compression
# --> 128 return wrapped_func(*args, **kwargs)
#
# File ~/Desktop/agents/.venv/lib/python3.12/site-packages/google/api_core/retry/retry_unary.py:294, in Retry.__call__.<locals>.retry_wrapped_func(*args, **kwargs)
#     290 target = functools.partial(func, *args, **kwargs)
#     291 sleep_generator = exponential_sleep_generator(
#     292     self._initial, self._maximum, multiplier=self._multiplier
#     293 )
# --> 294 return retry_target(
#     295     target,
#     296     self._predicate,
#     297     sleep_generator,
#     298     timeout=self._timeout,
#     299     on_error=on_error,
#     300 )
#
# File ~/Desktop/agents/.venv/lib/python3.12/site-packages/google/api_core/retry/retry_unary.py:147, in retry_target(target, predicate, sleep_generator, timeout, on_error, exception_factory, **kwargs)
#     145 while True:
#     146     try:
# --> 147         result = target()
#     148         if inspect.isawaitable(result):
#     149             warnings.warn(_ASYNC_RETRY_WARNING)
#
# File ~/Desktop/agents/.venv/lib/python3.12/site-packages/google/api_core/timeout.py:130, in TimeToDeadlineTimeout.__call__.<locals>.func_with_timeout(*args, **kwargs)
#     126         remaining_timeout = self._timeout
#     128     kwargs["timeout"] = remaining_timeout
# --> 130 return func(*args, **kwargs)
#
# File ~/Desktop/agents/.venv/lib/python3.12/site-packages/google/api_core/grpc_helpers.py:55, in _wrap_unary_errors.<locals>.error_remapped_callable(*args, **kwargs)
#      52 @functools.wraps(callable_)
#      53 def error_remapped_callable(*args, **kwargs):
#      54     try:
# ---> 55         return callable_(*args, **kwargs)
#      56     except grpc.RpcError as exc:
#      57         raise exceptions.from_grpc_error(exc) from exc
#
# File ~/Desktop/agents/.venv/lib/python3.12/site-packages/grpc/_interceptor.py:276, in _UnaryUnaryMultiCallable.__call__(self, request, timeout, metadata, credentials, wait_for_ready, compression)
#     267 def __call__(
#     268     self,
#     269     request: Any,
#    (...)    274     compression: Optional[grpc.Compression] = None,
#     275 ) -> Any:
# --> 276     response, ignored_call = self._with_call(
#     277         request,
#     278         timeout=timeout,
#     279         metadata=metadata,
#     280         credentials=credentials,
#     281         wait_for_ready=wait_for_ready,
#     282         compression=compression,
#     283     )
#     284     return response
#
# File ~/Desktop/agents/.venv/lib/python3.12/site-packages/grpc/_interceptor.py:328, in _UnaryUnaryMultiCallable._with_call(self, request, timeout, metadata, credentials, wait_for_ready, compression)
#     325     except Exception as exception:  # pylint:disable=broad-except
#     326         return _FailureOutcome(exception, sys.exc_info()[2])
# --> 328 call = self._interceptor.intercept_unary_unary(
#     329     continuation, client_call_details, request
#     330 )
#     331 return call.result(), call
#
# File ~/Desktop/agents/.venv/lib/python3.12/site-packages/google/ai/generativelanguage_v1beta/services/generative_service/transports/grpc.py:79, in _LoggingClientInterceptor.intercept_unary_unary(self, continuation, client_call_details, request)
#      64     grpc_request = {
#      65         "payload": request_payload,
#      66         "requestMethod": "grpc",
#      67         "metadata": dict(request_metadata),
#      68     }
#      69     _LOGGER.debug(
#      70         f"Sending request for {client_call_details.method}",
#      71         extra={
#    (...)     76         },
#      77     )
# ---> 79 response = continuation(client_call_details, request)
#      80 if logging_enabled:  # pragma: NO COVER
#      81     response_metadata = response.trailing_metadata()
#
# File ~/Desktop/agents/.venv/lib/python3.12/site-packages/grpc/_interceptor.py:314, in _UnaryUnaryMultiCallable._with_call.<locals>.continuation(new_details, request)
#     305 (
#     306     new_method,
#     307     new_timeout,
#    (...)    311     new_compression,
#     312 ) = _unwrap_client_call_details(new_details, client_call_details)
#     313 try:
# --> 314     response, call = self._thunk(new_method).with_call(
#     315         request,
#     316         timeout=new_timeout,
#     317         metadata=new_metadata,
#     318         credentials=new_credentials,
#     319         wait_for_ready=new_wait_for_ready,
#     320         compression=new_compression,
#     321     )
#     322     return _UnaryOutcome(response, call)
#     323 except grpc.RpcError as rpc_error:
#
# File ~/Desktop/agents/.venv/lib/python3.12/site-packages/grpc/_channel.py:1170, in _UnaryUnaryMultiCallable.with_call(self, request, timeout, metadata, credentials, wait_for_ready, compression)
#    1161 def with_call(
#    1162     self,
#    1163     request: Any,
#    (...)   1168     compression: Optional[grpc.Compression] = None,
#    1169 ) -> Tuple[Any, grpc.Call]:
# -> 1170     state, call = self._blocking(
#    1171         request, timeout, metadata, credentials, wait_for_ready, compression
#    1172     )
#    1173     return _end_unary_response_blocking(state, call, True, None)
#
# File ~/Desktop/agents/.venv/lib/python3.12/site-packages/grpc/_channel.py:1143, in _UnaryUnaryMultiCallable._blocking(self, request, timeout, metadata, credentials, wait_for_ready, compression)
#    1126 state.target = _common.decode(self._target)
#    1127 call = self._channel.segregated_call(
#    1128     cygrpc.PropagationConstants.GRPC_PROPAGATE_DEFAULTS,
#    1129     self._method,
#    (...)   1141     self._registered_call_handle,
#    1142 )
# -> 1143 event = call.next_event()
#    1144 _handle_event(event, state, self._response_deserializer)
#    1145 return state, call
#
# File src/python/grpcio/grpc/_cython/_cygrpc/channel.pyx.pxi:388, in grpc._cython.cygrpc.SegregatedCall.next_event()
#
# File src/python/grpcio/grpc/_cython/_cygrpc/channel.pyx.pxi:211, in grpc._cython.cygrpc._next_call_event()
#
# File src/python/grpcio/grpc/_cython/_cygrpc/channel.pyx.pxi:205, in grpc._cython.cygrpc._next_call_event()
#
# File src/python/grpcio/grpc/_cython/_cygrpc/completion_queue.pyx.pxi:97, in grpc._cython.cygrpc._latent_event()
#
# File src/python/grpcio/grpc/_cython/_cygrpc/completion_queue.pyx.pxi:80, in grpc._cython.cygrpc._internal_latent_event()
#
# File src/python/grpcio/grpc/_cython/_cygrpc/completion_queue.pyx.pxi:61, in grpc._cython.cygrpc._next()
#
# KeyboardInterrupt:

# %%
generated_question = answer

ques = [{'role':'user','content':f'Now give answer for this {generated_question}'}]

val = ques[0]['content']

soln = model.generate_content(val)

result = soln.text

display(Markdown(result))
# Out:
# This is indeed a challenging problem that effectively combines several advanced DSA techniques. The hint correctly points towards Binary Search on the Answer, but the standard two-pointer approach for counting subarrays with sum `<= X` needs careful adaptation (or replacement) when negative numbers are involved.
#
# Let's break down the solution:
#
# ### 1. High-Level Strategy: Binary Search on the Answer
#
# The core idea is to binary search for the `k`-th smallest sum. Suppose we want to check if a value `M` could be the `k`-th smallest sum. We need an efficient way to count how many subarrays have a sum less than or equal to `M`. Let's call this function `countSubarraysLE(M)`.
#
# *   If `countSubarraysLE(M) >= k`: It means there are `k` or more subarray sums less than or equal to `M`. This implies that the `k`-th smallest sum is `M` or something smaller. So, we try a smaller `M` (search in `[low, M]`).
# *   If `countSubarraysLE(M) < k`: It means there are fewer than `k` subarray sums less than or equal to `M`. This implies `M` is too small, and the `k`-th smallest sum must be larger. So, we try a larger `M` (search in `[M+1, high]`).
#
# ### 2. Efficient `countSubarraysLE(X)` Function
#
# This is the most critical and complex part, especially with negative numbers. The simple two-pointer (sliding window) technique often taught for problems like "count subarrays with sum `<= K` for positive numbers" breaks down when `nums` contains negative values. Why? Because removing an element from the left end of a window could *increase* the sum if that element was negative, invalidating the monotonic property usually exploited by the `(right - left + 1)` count.
#
# Instead, we use a combination of **prefix sums** and a **sorted data structure** (like a `std::multiset` in C++).
#
# Let `P[i]` be the prefix sum `nums[0] + ... + nums[i-1]`, with `P[0] = 0`.
# The sum of a subarray `nums[i...j]` is `P[j+1] - P[i]`.
# We want to count pairs `(i, j)` such that `P[j+1] - P[i] <= X`.
# Rearranging this, we get `P[i] >= P[j+1] - X`.
#
# So, for each `j` (from `0` to `N-1`):
# 1.  Calculate `current_prefix_sum = P[j+1]` (i.e., `nums[0] + ... + nums[j]`).
# 2.  We need to find how many `P[i]` values (where `0 <= i <= j`) satisfy `P[i] >= current_prefix_sum - X`.
# 3.  We maintain a `std::multiset` (or balanced BST) of all prefix sums encountered so far (`P[0], P[1], ..., P[j]`).
# 4.  Using `multiset.lower_bound(target)`, we can efficiently find the first prefix sum that is `>= target`. The number of elements from this iterator to `multiset.end()` gives us the count for the current `j`.
# 5.  Add `current_prefix_sum` to the `multiset` for the next iteration.
#
# This `countSubarraysLE(X)` function will have a time complexity of `O(N log N)` because each of the `N` operations (inserting a prefix sum, querying `lower_bound`) on the `multiset` takes `O(log N)` time.
#
# ### 3. Determining the Binary Search Range
#
# The search space `[low, high]` for subarray sums can be very large (`-10^{14}` to `10^{14}`). A simple `LLONG_MIN` and `LLONG_MAX` would work but might be too wide. We can determine tighter bounds by iterating through the array once:
#
# *   Initialize `min_overall_sum = 0`, `max_overall_sum = 0`.
# *   Maintain `current_prefix_sum`, `min_prefix_so_far = 0`, `max_prefix_so_far = 0`.
# *   For each `num` in `nums`:
#     *   `current_prefix_sum += num`.
#     *   `min_overall_sum = min(min_overall_sum, current_prefix_sum - max_prefix_so_far)`. (This captures the minimum sum of any subarray ending at the current position).
#     *   `max_overall_sum = max(max_overall_sum, current_prefix_sum - min_prefix_so_far)`. (This captures the maximum sum of any subarray ending at the current position).
#     *   `min_prefix_so_far = min(min_prefix_so_far, current_prefix_sum)`.
#     *   `max_prefix_so_far = max(max_prefix_so_far, current_prefix_sum)`.
#
# This approach correctly finds the actual minimum and maximum possible subarray sums, providing the tightest possible range for binary search.
#
# ### Complexity Analysis
#
# *   **Time Complexity:** `O(N * log N * log(Range))`
#     *   `log(Range)` for the binary search iterations. `Range` can be up to `2 * 10^{14}`, so `log(Range)` is approximately 48-50.
#     *   `O(N log N)` for each call to `countSubarraysLE(X)` due to `multiset` operations.
#     *   Total: `10^5 * 17 * 48` which is roughly `8 * 10^7` operations, feasible within typical time limits (1-2 seconds).
# *   **Space Complexity:** `O(N)`
#     *   For the `std::multiset` which can store up to `N` prefix sums in the worst case.
#
# ### C++ Solution
#
# ```cpp
# #include <vector>
# #include <algorithm>
# #include <set> // Required for std::multiset
# #include <limits> // Required for std::numeric_limits
#
# class Solution {
# public:
#     // Helper function to count subarrays with sum <= X
#     // This uses prefix sums and a multiset, which is crucial for handling negative numbers.
#     // Time complexity: O(N log N)
#     long long countSubarraysLE(const std::vector<int>& nums, long long X) {
#         long long count = 0;
#         long long current_prefix_sum = 0;
#
#         // A multiset to store prefix sums encountered so far.
#         // We insert 0 initially to account for subarrays that start from index 0.
#         // For example, if we want to count [0...j], its sum is P[j+1] - P[0].
#         std::multiset<long long> seen_prefix_sums;
#         seen_prefix_sums.insert(0);
#
#         for (int num : nums) {
#             current_prefix_sum += num;
#
#             // We are looking for subarrays (i, j) such that their sum (P[j+1] - P[i]) <= X.
#             // P[j+1] is `current_prefix_sum`.
#             // Rearranging the inequality: P[i] >= current_prefix_sum - X.
#
#             // Find the count of prefix sums in `seen_prefix_sums` that are
#             // greater than or equal to `current_prefix_sum - X`.
#             // `lower_bound(value)` returns an iterator to the first element that is not less than `value`.
#             auto it = seen_prefix_sums.lower_bound(current_prefix_sum - X);
#
#             // The number of elements from `it` to `seen_prefix_sums.end()` gives us the count.
#             count += std::distance(it, seen_prefix_sums.end());
#
#             // Add the current prefix sum to the multiset for future calculations.
#             seen_prefix_sums.insert(current_prefix_sum);
#         }
#         return count;
#     }
#
#     long long kthSmallestSubarraySum(std::vector<int>& nums, int k) {
#         // Step 1: Determine the binary search range [low, high].
#         // We calculate the actual minimum and maximum possible subarray sums to get tight bounds.
#         long long low = 0; // Will store the minimum possible subarray sum
#         long long high = 0; // Will store the maximum possible subarray sum
#
#         long long current_prefix_sum = 0;
#         long long min_prefix_so_far = 0; // Tracks minimum prefix sum encountered to find max subarray sum
#         long long max_prefix_so_far = 0; // Tracks maximum prefix sum encountered to find min subarray sum
#
#         // Initialize low/high with first element for N=1 case or general min/max element
#         // And then update using Kadane's logic adapted for min/max subarray sum
#         bool first_element_processed = false;
#         for (int num : nums) {
#             current_prefix_sum += num;
#
#             if (!first_element_processed) {
#                 low = num; // Smallest single element sum
#                 high = num; // Largest single element sum
#                 first_element_processed = true;
#             }
#
#             // Update minimum possible subarray sum
#             // A subarray sum ending at current_prefix_sum is current_prefix_sum - (some_previous_prefix_sum).
#             // To minimize this, we subtract the largest `max_prefix_so_far`.
#             low = std::min(low, current_prefix_sum - max_prefix_so_far);
#
#             // Update maximum possible subarray sum
#             // To maximize this, we subtract the smallest `min_prefix_so_far`.
#             high = std::max(high, current_prefix_sum - min_prefix_so_far);
#
#             // Update min/max prefix sums encountered so far
#             min_prefix_so_far = std::min(min_prefix_so_far, current_prefix_sum);
#             max_prefix_so_far = std::max(max_prefix_so_far, current_prefix_sum);
#         }
#
#         // Edge case: if nums contains only zeros, then low=0, high=0.
#         // If nums has negative numbers and all prefix_sums become negative, low might be negative.
#         // If nums has positive numbers, high might be positive.
#         // The above initialization and update loop handles this correctly.
#         // E.g. nums=[1,-2,3]: initial low=1, high=1.
#         // Then, after -2: low=min(1, -1-1)=-2, high=max(1,-1-0)=1.
#         // Then, after 3: low=min(-2, 2-1)=-2, high=max(1,2-(-1))=3.
#         // So the range is [-2, 3].
#
#         long long ans = high; // Initialize answer with a value that is certainly >= k-th sum (or just `low`)
#
#         // Step 2: Perform binary search on the range [low, high]
#         while (low <= high) {
#             long long mid = low + (high - low) / 2; // Prevent overflow with (low + high) / 2
#             long long count = countSubarraysLE(nums, mid);
#
#             if (count >= k) {
#                 // If there are 'k' or more subarrays with sum <= mid,
#                 // 'mid' could be our answer, or the answer is even smaller.
#                 ans = mid;
#                 high = mid - 1; // Try to find a smaller sum
#             } else {
#                 // If there are fewer than 'k' subarrays with sum <= mid,
#                 // 'mid' is too small; we need to look for a larger sum.
#                 low = mid + 1; // Search in the upper half
#             }
#         }
#
#         return ans;
#     }
# };
#
# ```
